# %%
# %matplotlib inline

import pandas as pd
import random
import matplotlib
import numpy
import matplotlib.pyplot as plt

try:
    del df
except:
    pass

df1 = pd.read_csv("stat.csv")

df1['statistics'].plot()

# %%
df2 = pd.DataFrame(data={
    'df1': df1['statistics']
         })
df2.plot.kde()

# %%
from scipy import stats
d1 = df2['df1']
print(stats.kstest(d1, 'norm', (d1.mean(), d1.std())))
# Out:
# KstestResult(statistic=0.3583261158829587, pvalue=0.0010039451470944538)
